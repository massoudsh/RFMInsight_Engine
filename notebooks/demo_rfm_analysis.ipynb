# %% [markdown]
# # 🚀 RFM Insight Engine - Complete Analysis Demo
#
# This notebook demonstrates the complete RFM analysis workflow using the integrated RFM Insight Engine.
#
# ## What you'll learn:
# - Load and process transaction data
# - Calculate RFM scores and segments
# - Perform machine learning clustering
# - Generate marketing strategies
# - Create comprehensive visualizations
# - Generate actionable reports

# %%
# Import required libraries
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Add src to path
sys.path.append('../src')

# Import RFM Insight Engine
from engine import RFMInsightEngine

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

print("📚 Libraries imported successfully!")
